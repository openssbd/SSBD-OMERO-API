# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# HTTP library
import requests

# %% [markdown]
# # 1. Check a HTTP session to SSBD using the requests library

# %%
SSBD_BASE_URL = "http://ssbd.qbic.riken.jp/image"

url = SSBD_BASE_URL
if requests.session().get(url).status_code == 200:
    print("Successfully connected to SSBD")
else:
    print("Failed to connect to SSBD")
print(url)
# Out:
# Successfully connected to SSBD
# http://ssbd.qbic.riken.jp/image

# %%
# Sample in Kyoda imagesets
IMAGE_ID = 25021

# Sample in Takayama imagesets
#IMAGE_ID = 36874

# %% [markdown]
# # 2. Get shortcut URLs of image

# %%
image_url = "{base}/webclient/?show=image-{image_id}"
image_viewer = "{base}/webclient/img_detail/{image_id}/"
thumbnail_url = "{base}/webclient/render_thumbnail/{image_id}/"
attributes_url = "{base}/webclient/api/annotations/?type=map&image={image_id}"

print('Image link:', image_url.format(**{'base': SSBD_BASE_URL, 'image_id': IMAGE_ID}))
print('Image viewer link:', image_viewer.format(**{'base': SSBD_BASE_URL, 'image_id': IMAGE_ID}))
print('Thumbnail URL:', thumbnail_url.format(**{'base': SSBD_BASE_URL, 'image_id': IMAGE_ID}))
print('Attributes URL:', attributes_url.format(**{'base': SSBD_BASE_URL, 'image_id': IMAGE_ID}))
# Out:
# Image link: http://ssbd.qbic.riken.jp/image/webclient/?show=image-25021
# Image viewer link: http://ssbd.qbic.riken.jp/image/webclient/img_detail/25021/
# Thumbnail URL: http://ssbd.qbic.riken.jp/image/webclient/render_thumbnail/25021/
# Attributes URL: http://ssbd.qbic.riken.jp/image/webclient/api/annotations/?type=map&image=25021

# %% [markdown]
# # 3. Get image metadata

# %%
TMP_URL = "{base}/webclient/imgData/{image_id}/"
qs = {'base': SSBD_BASE_URL, 'image_id': IMAGE_ID}

url = TMP_URL.format(**qs)
r = requests.session().get(url)


if r.status_code == 200:
    metadata = r.json()
    
    print ("ProjectName:", metadata['meta']['projectName'])
    print ("Dataset:", metadata['meta']['datasetName'])
    print ("X:", metadata['size']['width'])
    print ("Y:", metadata['size']['height'])
    print ("Z:", metadata['size']['z'])
    print ("T:", metadata['size']['t'])
    print ("C:", metadata['size']['c'])
    print ("PixelsType: ", metadata['meta']['pixelsType'])
    print ("PixwlRange: ", metadata['pixel_range'][1])
    
    print ("\n", metadata)
print(url)
# Out:
# ProjectName: 2-Kyoda-WormEmbryoRNAi
# Dataset: wt_N2_030131_01
# X: 600
# Y: 600
# Z: 66
# T: 1
# C: 1
# PixelsType:  uint16
# PixwlRange:  65535
#
#  {'init_zoom': 0, 'tiles': False, 'perms': {'canAnnotate': False, 'canEdit': False, 'canDelete': False, 'canLink': False}, 'rdefs': {'defaultT': 0, 'model': 'greyscale', 'invertAxis': False, 'projection': 'normal', 'defaultZ': 33}, 'pixel_range': [0, 65535], 'interpolate': True, 'channels': [{'color': '808080', 'emissionWave': None, 'label': '0', 'window': {'max': 2538.0, 'end': 2538.0, 'start': 435.0, 'min': 435.0}, 'active': True, 'reverseIntensity': False}], 'meta': {'projectName': '2-Kyoda-WormEmbryoRNAi', 'imageId': 25021, 'imageAuthor': 'public data', 'imageTimestamp': 1478871804.0, 'pixelsType': 'uint16', 'datasetId': 140, 'projectDescription': 'See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737', 'datasetName': 'wt_N2_030131_01', 'wellSampleId': '', 'projectId': 1, 'imageDescription': 'See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D851', 'wellId': '', 'imageName': 'img0000.ipm', 'datasetDescription': 'See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D851'}, 'id': 25021, 'pixel_size': {'y': None, 'x': None, 'z': None}, 'size': {'width': 600, 'c': 1, 'z': 66, 't': 1, 'height': 600}, 'split_channel': {'c': {'width': 1206, 'gridy': 1, 'border': 2, 'gridx': 2, 'height': 604}, 'g': {'width': 604, 'gridy': 1, 'border': 2, 'gridx': 1, 'height': 604}}}
# http://ssbd.qbic.riken.jp/image/webclient/imgData/25021/

# %% [markdown]
# # 4. Get image key-value annotation

# %%
TMP_URL = "{base}/webclient/api/annotations/?type=map&{type}={image_id}"
qs = {'base': SSBD_BASE_URL, 'type': 'image', 'image_id': IMAGE_ID}

url = TMP_URL.format(**qs)
for a in requests.session().get(url).json()['annotations']:
    namespace = a['ns']
    for v in a['values']:
        key = v[0]
        value = v[1]
        print (key, value)
    print ("\n", a)
print (url)
# Out:
# License CC BY-NC-SA
# Contactname Shuichi Onami
# Organization RIKEN
# Department Quantitative Biology Center
# Laboratory Laboratory for Developmental Dynamics
# Contributers Eru Adachi, Eriko Masuda, Yoko Nagai, Yoko Suzuki, Taeko Oguro, Koji Kyoda, Shuichi Onami
# Organism C. elegans
# PubMedID 23172286
#
#  {'description': None, 'class': 'MapAnnotationI', 'date': '2016-11-15T02:40:01Z', 'link': {'owner': {'id': 2}, 'date': '2016-11-15T02:40:01Z', 'id': 20640, 'parent': {'id': 25021, 'name': 'img0000.ipm', 'class': 'ImageI'}, 'permissions': {'canAnnotate': False, 'canEdit': False, 'canDelete': False, 'canLink': False}}, 'owner': {'id': 2}, 'values': [['License', 'CC BY-NC-SA'], ['Contactname', 'Shuichi Onami'], ['Organization', 'RIKEN'], ['Department', 'Quantitative Biology Center'], ['Laboratory', 'Laboratory for Developmental Dynamics'], ['Contributers', 'Eru Adachi, Eriko Masuda, Yoko Nagai, Yoko Suzuki, Taeko Oguro, Koji Kyoda, Shuichi Onami'], ['Organism', 'C. elegans'], ['PubMedID', '23172286']], 'ns': 'openmicroscopy.org/omero/client/mapAnnotation', 'id': 20876, 'permissions': {'canAnnotate': False, 'canEdit': False, 'canDelete': False, 'canLink': False}}
# http://ssbd.qbic.riken.jp/image/webclient/api/annotations/?type=map&image=25021

# %% [markdown]
# # 5. Get list of projects

# %%
TMP_URL = "{base}/webgateway/proj/list"
qs = {'base': SSBD_BASE_URL }

url = TMP_URL.format(**qs)
for a in requests.session().get(url).json():
    print (a)
    print (a['id'], a['name'])

print(url)
# Out:
# {'description': 'See details in Takayama and Onami. (2016) Cell Reports, 15(3), 625-637', 'id': 11, 'name': '12-Takayama-Oocyte'}
# 11 12-Takayama-Oocyte
# {'description': 'See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737', 'id': 1, 'name': '2-Kyoda-WormEmbryoRNAi'}
# 1 2-Kyoda-WormEmbryoRNAi
# {'description': 'See details in Toyoshima et al. (2016) PLoS Computational Biology, 12(6): e1004970', 'id': 4, 'name': '11-Toyoshima-NeuAct'}
# 4 11-Toyoshima-NeuAct
# {'description': 'See details in Komatsuzaki et al. (2015) Small, 11(12):1396-1401', 'id': 10, 'name': '10-Komatsuzaki-MolDyn'}
# 10 10-Komatsuzaki-MolDyn
# {'description': 'See details in Kunida et al. (2012) Journal of Cell Science, 125(10): 2381-2392', 'id': 5, 'name': '18-Kunida-MolDynRho'}
# 5 18-Kunida-MolDynRho
# {'description': 'See details in Tanaka and Fujita (2015) Sensors and Actuators B: Chemical, 210(1): 267-272', 'id': 7, 'name': '16-Tanaka-FluidDyn'}
# 7 16-Tanaka-FluidDyn
# {'description': 'See details in Watabe et al. (2015) PLoS One, 10(7): e0130089', 'id': 2, 'name': '13-Watabe-MolDyn'}
# 2 13-Watabe-MolDyn
# {'description': 'See details in Bashar et al. (2012) PLoS ONE 7, e35550.', 'id': 9, 'name': '8-Bashar-MouseEmbryo'}
# 9 8-Bashar-MouseEmbryo
# {'description': 'See details in Ochiai et al. (2015) Nucleic Acids Research, 43(19): e127', 'id': 12, 'name': '14-Ochiai-MolDynMS2'}
# 12 14-Ochiai-MolDynMS2
# {'description': 'See details in Harima et al. (2013) Cell Reports, 3(1): 1-7', 'id': 3, 'name': '15-Harima-GeneExp'}
# 3 15-Harima-GeneExp
# {'description': 'See details in Tanaka (2014) Micromachines, 5(2): 289-299', 'id': 8, 'name': '19-Tanaka-FluidDyn'}
# 8 19-Tanaka-FluidDyn
# {'description': 'See details in Aoki et al. (2013) Molecular Cell, 52(4): 529-540', 'id': 6, 'name': '17-Aoki-MolDyn'}
# 6 17-Aoki-MolDyn
# {'description': 'See details in Yasui et al. (2014) PLoS Computational Biology, 10(9): e1003817.', 'id': 51, 'name': '21-Yasui-MolDynPTEN'}
# 51 21-Yasui-MolDynPTEN
# {'description': 'See details in Kondo and Hayashi (2013) Nature, 494, 125-129.', 'id': 52, 'name': '22-Kondo-CellDyn'}
# 52 22-Kondo-CellDyn
# {'description': 'See details in Shirai et al. (2016) PNAS, 113(1): E81-E90.', 'id': 53, 'name': '23-Shirai-ESCellTissue'}
# 53 23-Shirai-ESCellTissue
# {'description': 'See details in Kanemura et al. (2013) Scientific Reports, 3(2334): 2334.', 'id': 54, 'name': '24-Kanemura-iPSCellDyn'}
# 54 24-Kanemura-iPSCellDyn
# {'description': 'See details in Ke et al. (2013) Nature Neuroscience, 16: 1154-1161.', 'id': 55, 'name': '25-Ke-SeeDB'}
# 55 25-Ke-SeeDB
# {'description': 'See details in Kinoshita et al. (2016) Retinal Cell Biology, 57(1): 153-161.', 'id': 56, 'name': '26-Kinoshita-iPSCellDyn'}
# 56 26-Kinoshita-iPSCellDyn
# {'description': 'See details in Iwasaki et al. (2016) PLoS ONE, 11(7): e0158282.', 'id': 57, 'name': '27-Iwasaki-iPSCellDyn'}
# 57 27-Iwasaki-iPSCellDyn
# {'description': 'See details in Assawachananont et al. (2014) Stem Cell Reports, 2(5): 662-674.', 'id': 58, 'name': '28-Assawachananont-iPSCellTissue'}
# 58 28-Assawachananont-iPSCellTissue
# {'description': 'See details in Ke et al. (2016) Cell Reports, 14: 2718-2732.', 'id': 59, 'name': '29-Ke-SeeDB2'}
# 59 29-Ke-SeeDB2
# {'description': 'See details in Inomata et al. (2013) Cell, 153(6): 1296-1311.', 'id': 60, 'name': '30-Inomata-CellDyn'}
# 60 30-Inomata-CellDyn
# {'description': 'See details in Matsuda et al. (2012) Sci. Signal., 5, ra31.', 'id': 61, 'name': '31-Matsuda-SigDyn'}
# 61 31-Matsuda-SigDyn
# {'description': 'See details in Matsuda et al. (2015) Nat. Commun., 6, 6195', 'id': 62, 'name': '32-Matsuda-SigDyn'}
# 62 32-Matsuda-SigDyn
# {'description': 'See details in Yamao et al. (2015) Scientific Reports, 5: 17527.', 'id': 63, 'name': '33-Yamao-MolDynRho'}
# 63 33-Yamao-MolDynRho
# {'description': 'See details in Hayashi and Okada (2015) Mol Biol Cell, 26(9): 1743-1751.', 'id': 64, 'name': '34-Hayashi-CellDynSDSRM'}
# 64 34-Hayashi-CellDynSDSRM
# {'description': 'See details in Yonemura (2014) PLoS ONE, 9(11): e112922.', 'id': 65, 'name': '35-Yonemura-CellDyn'}
# 65 35-Yonemura-CellDyn
# {'description': 'See details in Torisawa et al. (2016) Biophysical Journal, 111(2): 373-385.', 'id': 66, 'name': '36-Torisawa-MolDynEg5'}
# 66 36-Torisawa-MolDynEg5
# {'description': 'See details in Arata et al. (2016) Cell Reports, 16, 1-13.', 'id': 67, 'name': '37-Arata-MolDynPar2'}
# 67 37-Arata-MolDynPar2
# {'description': 'See details in Inoue and Kondo (2016) Scientific Reports, 6, 33689.', 'id': 68, 'name': '38-Inoue-ShellStruct'}
# 68 38-Inoue-ShellStruct
# {'description': 'See details in Shibata et al. (2012) J. Cell Sci., 125: 5138-5150.', 'id': 69, 'name': '39-Shibata-MolDynPTEN'}
# 69 39-Shibata-MolDynPTEN
# {'description': 'See details in Sakakibara et al. (2015) Nat Commun. 2013; 4:2212.', 'id': 70, 'name': '40-Sakakibara-KTDyn'}
# 70 40-Sakakibara-KTDyn
# {'description': 'See details in Takai et al. (2015) PNAS, 112(14): 4352-4356.', 'id': 71, 'name': '43-Takai-SubcellStructONL'}
# 71 43-Takai-SubcellStructONL
# {'description': 'See details in Azuma and Onami (2017) BMC Bioinformatics, 18(1): 307.', 'id': 101, 'name': '20-Azuma-WormMembrane'}
# 101 20-Azuma-WormMembrane
# {'description': 'See details in Susaki et al. (2014) Cell, 157(3): 726–739.', 'id': 106, 'name': '48-Susaki-MouseBrainCUBIC'}
# 106 48-Susaki-MouseBrainCUBIC
# {'description': 'See details in Susaki et al. (2015) Nature Protocols, 10: 1709–1727.', 'id': 105, 'name': '49-Susaki-MouseBrainCUBIC'}
# 105 49-Susaki-MouseBrainCUBIC
# {'description': 'See details in Tainaka et al. (2014) Cell, 159(4): 911–924.', 'id': 104, 'name': '50-Tainaka-MouseBodyCUBIC'}
# 104 50-Tainaka-MouseBodyCUBIC
# {'description': 'See details in Suzuki et al. (2015) Genes to Cells, 21(4): 358-369.', 'id': 102, 'name': '52-Suzuki-FrogTailDyn'}
# 102 52-Suzuki-FrogTailDyn
# {'description': 'See details in Ichimura et al. (2016) Scientific Reports, 6: 37562.', 'id': 103, 'name': '53-Ichimura-CellDyn'}
# 103 53-Ichimura-CellDyn
# http://ssbd.qbic.riken.jp/image/webgateway/proj/list

# %% [markdown]
# # 6. Get list of datasets in the given project

# %%
PROJECT_ID = 1
TMP_URL = "{base}/webgateway/proj/{project_id}/children/"
# 137 wt_N2_030116_02 180
# 138 wt_N2_030124_02 180
# 139 wt_N2_030127_01 180
# 140 wt_N2_030131_01 180
# 141 wt_N2_030131_02 180
# 142 wt_N2_030131_03 180
# 143 wt_N2_030203_01 180
# 144 wt_N2_030203_02 180
# 145 wt_N2_030204_03 180
# 146 wt_N2_030206_01 180
# 147 wt_N2_030207_01 180
# 148 wt_N2_030207_02 180
# 149 wt_N2_030210_01 180
# 150 wt_N2_030210_02 180
# 151 wt_N2_030210_03 180
# 152 wt_N2_030212_01 180
# 153 wt_N2_030212_02 180
# 154 wt_N2_030212_03 180
# 155 wt_N2_030213_02 180
# 156 wt_N2_030213_03 180
# 157 wt_N2_030213_04 180
# 158 wt_N2_030214_01 180
# 159 wt_N2_030214_03 180
# 160 wt_N2_030214_04 180
# 161 wt_N2_030217_02 180
# 162 wt_N2_030217_04 180
# 163 wt_N2_030218_01 180
# 164 wt_N2_030218_02 180
# 165 wt_N2_030218_04 180
# 166 wt_N2_030218_05 180
# 167 wt_N2_030221_01 180
# 168 wt_N2_030221_02 180
# 169 wt_N2_030221_03 180
# 170 wt_N2_030221_05 180
# 171 wt_N2_030224_01 180
# 172 wt_N2_030224_02 180
# 173 wt_N2_030224_04 180
# 174 wt_N2_030228_02 180
# 175 wt_N2_030228_03 180
# 176 wt_N2_030303_01 180
# 177 wt_N2_030304_01 180
# 178 wt_N2_030304_02 180
# 179 wt_N2_030304_05 180
# 180 wt_N2_030305_01 180
# 181 wt_N2_030305_02 180
# 182 wt_N2_030305_04 180
# 183 wt_N2_030306_01 180
# 184 wt_N2_070111_02 180
# 185 wt_N2_070111_03 180
# 186 wt_N2_071220_01 180
# http://ssbd.qbic.riken.jp/image/webgateway/proj/1/children/

# %% [markdown]
# # 7. Get list of images in the given dataset

# %%
DATASET_ID = 1
TMP_URL = "{base}/webgateway/dataset/{dataset_id}/children/"
qs = {'base': SSBD_BASE_URL, 'dataset_id': DATASET_ID}

url = TMP_URL.format(**qs)
for a in requests.session().get(url).json():
    print (a['id'], a['name'])

print(url)
# Out:
# 1 img0000.ipm
# 2 img0001.ipm
# 3 img0002.ipm
# 4 img0003.ipm
# 5 img0004.ipm
# 6 img0005.ipm
# 7 img0006.ipm
# 8 img0007.ipm
# 9 img0008.ipm
# 10 img0009.ipm
# 11 img0010.ipm
# 12 img0011.ipm
# 13 img0012.ipm
# 14 img0013.ipm
# 15 img0014.ipm
# 16 img0015.ipm
# 17 img0016.ipm
# 18 img0017.ipm
# 19 img0018.ipm
# 20 img0019.ipm
# 21 img0020.ipm
# 22 img0021.ipm
# 23 img0022.ipm
# 24 img0023.ipm
# 25 img0024.ipm
# 26 img0025.ipm
# 27 img0026.ipm
# 28 img0027.ipm
# 29 img0028.ipm
# 30 img0029.ipm
# 31 img0030.ipm
# 32 img0031.ipm
# 33 img0032.ipm
# 34 img0033.ipm
# 35 img0034.ipm
# 36 img0035.ipm
# 37 img0036.ipm
# 38 img0037.ipm
# 39 img0038.ipm
# 40 img0039.ipm
# 41 img0040.ipm
# 42 img0041.ipm
# 43 img0042.ipm
# 44 img0043.ipm
# 45 img0044.ipm
# 46 img0045.ipm
# 47 img0046.ipm
# 48 img0047.ipm
